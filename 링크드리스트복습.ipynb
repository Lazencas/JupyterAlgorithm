# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# %%
class linkMG:
 def __init__(self,data):
  self.head = Node(data)

 def add(self,data):
    #헤드가 없을때 값을 넣고 헤드로 만든다
    node = self.head
    if node == '':
        node = Node(data)   
    else:
      while node.next:
        node = node.next
      node.next = Node(data)
      
 def desc(self):
    node = self.head
    while node.next:
        print(node.data)
        node = node.next
    print(node.data)
    
 def insert(self,predata,data):
    node = self.head
    search = True
    temp = None
    while node.next:
        if node.data == predata:            
            node_next = node.next
            node.next = Node(data)
            print("디버깅" + str(node_next))
            #이 위까진 잘됨
            Node(data).next = node_next         
            search = False
        else:
            node = node.next

# %%
link = linkMG(0)

# %%
link.add(1)
link.add(2)
link.add(3)

# %%
link.desc()
# Out:
# 0
# 1
# 2
# 3

# %%
link.insert(1,10)
# Out:
# 디버깅<__main__.Node object at 0x000002D9495395E0>
# 디버깅<__main__.Node object at 0x000002D949539220>
# 디버깅<__main__.Node object at 0x000002D9495395E0>
# 디버깅<__main__.Node object at 0x000002D949539220>
# 디버깅<__main__.Node object at 0x000002D9495395E0>
# 디버깅<__main__.Node object at 0x000002D949539220>
# 디버깅<__main__.Node object at 0x000002D9495395E0>
# 디버깅<__main__.Node object at 0x000002D949539220>
# 디버깅<__main__.Node object at 0x000002D9495395E0>
# 디버깅<__main__.Node object at 0x000002D949539220>
# 디버깅<__main__.Node object at 0x000002D9495395E0>
# 디버깅<__main__.Node object at 0x000002D949539220>
# 디버깅<__main__.Node object at 0x000002D9495395E0>
# 디버깅<__main__.Node object at 0x000002D949539220>
# 디버깅<__main__.Node object at 0x000002D9495395E0>
# 디버깅<__main__.Node object at 0x000002D949539220>
# 디버깅<__main__.Node object at 0x000002D9495395E0>
# 디버깅<__main__.Node object at 0x000002D949539220>
# 디버깅<__main__.Node object at 0x000002D9495395E0>
# 디버깅<__main__.Node object at 0x000002D949539220>
# ...

# %%
link.desc()
# Out:
# 0
# 1
# 10

# %%
a = 10
print("이게출력이안됨?"+str(a))
# Out:
# 이게출력이안됨?10
